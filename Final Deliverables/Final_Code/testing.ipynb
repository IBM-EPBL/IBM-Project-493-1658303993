# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\nandhini\anaconda3\lib\site-packages (2.11.0)

# %%
from keras.models import load_model
from keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input

# %%
model=load_model("final.h5")

# %%
from tensorflow.keras.preprocessing import image

# %%
img=image.load_img("imm.png",target_size=(299,299))

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
x=preprocess_input(x)

# %%
x.shape
# Out:
# (1, 299, 299, 3)

# %%
output=np.argmax(model.predict(x), axis=1)
# Out:
# 1/1 [==============================] - 0s 217ms/step

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x18001C572B0>

# %%
output==0,output==1,output==2,output==3,output==4
# Out:
# (array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]))

# %%
index = [' No Diabetic Retinopathy ', ' Mild NPDR ',
                 ' Moderate NPDR ', ' Severe NPDR ', ' Proliferative DR ']
result = str(index[output[0]])
print(result)
# Out:
#  Proliferative DR
